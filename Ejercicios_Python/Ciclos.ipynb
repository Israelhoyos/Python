# %% [markdown]
#  # <center><font color='green'>Ciclos</font></center>

# %% [markdown]
#  # <font color='green'>Ciclo for</font>

# %%
frutas = ["manzana", "banana", "kiwi", "naranja"]

for fruta in frutas:
    print(fruta)
# Out:
# manzana
# banana
# kiwi
# naranja

# %% [markdown]
# También podemos utilizar el **ciclo for** para iterar sobre una cadena de caracteres:

# %%
mensaje = "Hola, mundo!"

for caracter in mensaje:
    print(caracter)
# Out:
# H
# o
# l
# a
# ,
#
# m
# u
# n
# d
# o
# !

# %% [markdown]
# Los diccionarios tienen una forma especial de recorrerse utilizando un ciclo for. Observa el siguiente bloque.

# %%
refranes = {"Perro que ladra": "no muerde",
            "A quien madruga": "Dios le ayuda",
            "No dejes para mañana": "lo que puedas hacer hoy"}

for llave, valor in refranes.items():
    refran_completo = llave + ", " + valor
    print(refran_completo)
# Out:
# Perro que ladra, no muerde
# A quien madruga, Dios le ayuda
# No dejes para mañana, lo que puedas hacer hoy

# %% [markdown]
#  # <font color='green'>Ciclo while</font>

# %%
numero = 1

while numero <= 5:
    print(numero)
    numero = numero + 1
# Out:
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# También podemos utilizar el **ciclo while** para repetir un bloque de código hasta que el usuario ingrese un valor específico. Por ejemplo:

# %%
respuesta = ""

while
:
    respuesta = input("¿Quieres finalizar? (s/n)")

print("Fin del programa.")
# Out:
# ¿Quieres finalizar? (s/n)e
# ¿Quieres finalizar? (s/n)f
# ¿Quieres finalizar? (s/n)g
# ¿Quieres finalizar? (s/n)n
# ¿Quieres finalizar? (s/n)s
# Fin del programa.

# %% [markdown]
# **Explicación:** Este código le pedirá al usuario que ingrese "s" o "n" para decidir si quiere finalizar o no. Mientras el usuario no ingrese "s", el ciclo se seguirá repitiendo. Cuando el usuario finalmente ingrese "s", el ciclo se detendrá y el programa imprimirá "Fin del programa.".

# %%
opcion = 0

while opcion != 3:
    print("¿Qué acción deseas realizar?")
    print("1. Saludar")
    print("2. Sumar dos números")
    print("3. Salir")

    opcion = int(input("Ingrese su opción: "))

    if opcion == 1:
        print("¡Hola, mundo!")
    elif opcion == 2:
        num1, num2 = map(int, input("Ingrese dos números separados por espacio: ").split())
        print("El resultado de la suma es:", num1 + num2)
    elif opcion == 3:
        print("Adiós.")
    else:
        print("Opción inválida.")
# Out:
# ¿Qué acción deseas realizar?
# 1. Saludar
# 2. Sumar dos números
# 3. Salir
# Ingrese su opción: 8
# Opción inválida.
# ¿Qué acción deseas realizar?
# 1. Saludar
# 2. Sumar dos números
# 3. Salir
# Ingrese su opción: 3
# Adiós.

# %% [markdown]
# **Explicación:** En este ejemplo, el **ciclo while** se ejecuta hasta que el usuario seleccione la opción "3" para salir. Si el usuario selecciona la opción "1", el programa imprime "¡Hola, mundo!". Si el usuario selecciona la opción "2", el programa le pide al usuario que ingrese dos números separados por espacio y luego imprime el resultado de la suma. Si el usuario selecciona una opción inválida, el programa le informa al usuario que su opción es inválida y vuelve a mostrar el menú.

# %% [markdown]
#  # <font color='green'>Ciclos anidados</font>

# %%
matriz = [[1, 2, 3], [4, 5, 6], [7, 8, 9]]
suma = 0

for fila in matriz:
    for elemento in fila:
        suma += elemento
        print(suma)

# %% [markdown]
# Podemos observar que primero recorremos cada elemento de la matriz (que, a su vez, son listas). Para cada uno de estos elementos, hacemos a su vez un recorrido por ellos.
#
# ¿Qué significa "suma += elemento"?

# %% [markdown]
#  # <font color='green'>Break</font>
# El comando **break** nos permite terminar un ciclo verificando una condición, antes de que se complete.
#
# Por ejemplo: queremos que el programa le solicite una contraseña al usuario, con un máximo de 3 intentos (luego de los cuales se bloquea). Podemos implementar esto de la siguiente manera:

# %%
password="adivina"
intentos = 0

while intentos < 3:
    respuesta = input("Ingrese contraseña: ")
    intentos+=1
    restantes=3-intentos
    if respuesta != password and restantes !=0:
        print(f"Contraseña incorrecta. Le quedan {restantes} intentos")
    else:
        break

if respuesta == password:
    print(f"¡Acceso permitido!")
else:
    print(f"Acceso denegado")
# Out:
# Ingrese contraseña: perro
# Contraseña incorrecta. Le quedan 2 intentos
# Ingrese contraseña: araña
# Contraseña incorrecta. Le quedan 1 intentos
# Ingrese contraseña: adivina
# ¡Acceso permitido!

# %% [markdown]
#  # <center><font color='green'>Ejercicios</font></center>

# %% [markdown]
#  ## <font color='green'>Ejercicio 1</font>
#
# Escribir un programa que le pregunte al usuario su edad y le muestre un mensaje dependiendo de la respuesta: "eres menor de edad", "eres mayor de edad" o "eres adulto mayor".

# %%
# Pedir al usuario que ingrese su edad
edad = int(input("¿Cuántos años tienes? "))

# Verificar la edad y mostrar un mensaje correspondiente
if edad < 18:
    print("Eres menor de edad")
elif edad >= 18 and edad < 65:
    print("Eres mayor de edad")
else:
    print("Eres un adulto mayor")
# Out:
# ¿Cuántos años tienes? 56
# Eres mayor de edad

# %% [markdown]
#  ## <font color='green'>Ejercicio 2</font>
#
# Escribir un programa que pida al usuario dos números enteros y los compare.
#
# - Si el primer número es mayor que el segundo, el programa debe imprimir **"El primer número es mayor"**.
# - Si el segundo número es mayor que el primero, el programa debe imprimir **"El segundo número es mayor"**.
# - Si los dos números son iguales, el programa debe imprimir **"Los números son iguales"**.

# %%
num1 = int(input("Introduce el primer número: "))
num2 = int(input("Introduce el segundo número: "))

if num1 > num2:
    print("El primer número es mayor")
elif num2 > num1:
    print("El segundo número es mayor")
else:
    print("Los números son iguales")

# %% [markdown]
#  ## <font color='green'>Ejercicio 3</font>
#
# Escribir un programa en el que se genera un número del 1 al 20, al azar. El concursante tiene 5 intentos para adivinarlo, ingresando valores. Ante cada respuesta se le retroalimenta "el número es mayor"o "el número es menor", y se le avisa si acierta. Si consume los intentos, se le informa y dice el número pedido.

# %%
import random
a=random.randint(1,20)
intentos = 0

while intentos < 5:
    respuesta = int(input("Ingresa un número: "))
    intentos+=1
    if respuesta < a:
        print("El número es mayor")
    if respuesta > a:
        print("El número es menor")
    if respuesta == a:
        break

if respuesta == a:
    print(f"¡Has adivinado!")
else:
    print(f"¡Has fallado! El número es {a}")
# Out:
# Ingresa un número: 50
# El número es menor
# Ingresa un número: 25
# El número es menor
# Ingresa un número: 12
# El número es menor
# Ingresa un número: 9000
# El número es menor
# Ingresa un número: 1
# El número es mayor
# ¡Has fallado! El número es 3

# %% [markdown]
#  # <center><font color='green'>Soluciones</font></center>

# %%
# Pedir al usuario que ingrese su edad
edad = int(input("¿Cuántos años tienes? "))

# Verificar la edad y mostrar un mensaje correspondiente
if edad < 18:
    print("Eres menor de edad")
elif edad >= 18 and edad < 65:
    print("Eres mayor de edad")
else:
    print("Eres un adulto mayor")

# %%
num1 = int(input("Introduce el primer número: "))
num2 = int(input("Introduce el segundo número: "))

if num1 > num2:
    print("El primer número es mayor")
elif num2 > num1:
    print("El segundo número es mayor")
else:
    print("Los números son iguales")

# %%
import random
a=random.randint(1,20)
intentos = 0

while intentos < 5:
    respuesta = int(input("Ingresa un número: "))
    intentos+=1
    if respuesta < a:
        print("El número es mayor")
    if respuesta > a:
        print("El número es menor")
    if respuesta == a:
        break

if respuesta == a:
    print(f"¡Has adivinado!")
else:
    print(f"¡Has fallado! El número es {a}")
